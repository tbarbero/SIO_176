# %%
# %matplotlib inline

# %% [markdown]
# # Directions:
# 1.   Compute the mixed-layer depth from each one of your profiles [ Only need about a year -- to observe seasonal variability]. You need to identify a metric of your choice [temperature -- uniform within mixed layer due to mixing -- then drops] to identify the mixed layer, that you think makes sense for your data, and explain how you chose it. You may want to check its applicability for a number of profiles. In the presentation you will need to convince your peers that your mixed layer was defined appropriately.
# 2.   Calculate the integrated heat content (Q, in Joules/m2) of your profiles from the surface to a fixed depth. This depth should be equal to or greater than the maximum mixed layer depth estimated during your data-period.
# 3.   Calculate the vertically averaged absolute salinity for the same depth as in 2) and plot how it varies in time.
# 4.   Using your plots of mixed-layer depth, Q, vertically averaged salinity, describe the seasonal variation in these properties from your float data.
# 5.   Show one cool or unexpected thing you found in the data. Your choice.

# %% [markdown]
# Mixed layers caused by mixing. In winter, storms prevalent which cause mixing within the first 1000m. (uniform temperature/salinity)
# The Labrador Sea is a cold and salinity minimum region, (freshwater) relative to surrounding bodies, is it a better idea to look at salinity or temperature for mixed layer?

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.io import loadmat
import cartopy.crs as ccrs
from datetime import datetime
import gsw
import math
#nice stuff
import cartopy.feature as cfeature

# %%
data = loadmat('/Users/tyler/Desktop/SIO176/HW7/float5903390.mat')

# %%
data.keys()
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'date', 'latitude', 'longitude', 'pressure', 'salinity', 'temperature'])

# %%
temp = data['temperature']
pracsal = data['salinity']
pres = data['pressure']
long = np.transpose(data['longitude'])
lat = np.transpose(data['latitude'])
date = data['date']

# %%
SA = gsw.SA_from_SP(pracsal,pres,long,lat)
PT = gsw.pt_from_t(SA,temp,pres,p_ref=0)
CT = gsw.CT_from_pt(SA,PT)
rho = gsw.rho(SA,CT,pres)

# %% [markdown]
# # 1. Compute the mixed layer depth for ~ 1 year of data to analyze season variability of the mixed layer

# %% [markdown]
# # Plot the trajectory to see where profiles are located

# %%
fig = plt.figure(figsize=(20,20))
ax = plt.axes(projection=ccrs.PlateCarree())
#ax.stock_img()
#ax.add_feature(cfeature.OCEAN)
ax.add_feature(cfeature.LAND)
ax.add_feature(cfeature.LAKES)
ax.add_feature(cfeature.RIVERS)
ax.coastlines(color='black', linewidth=1)
#--------------------------------------------------------------------
# code to plot all profile positions
# i = range(0,len(lat))
# for i in range(0,len(i)):
#     plt.plot(long[i],lat[i],marker='o',c='blue',markersize=5)
#     plt.text(long[i],lat[i],i,fontsize=10)
#--------------------------------------------------------------------
# plotting positions of data within same region
prof_list = []
for i in range(0,len(lat)):
    if float(lat[i]) >= 54.457 and float(lat[i]) <= 56.194 and float(long[i]) >= -52.654 and float(long[i]) <= -48.405:
        plt.plot(long[i],lat[i],marker='o',c='blue',markersize=5)
        plt.text(long[i],lat[i],i,fontsize=10)
        prof_list=np.append(prof_list,i)
#--------------------------------------------------------------------
# gathering list of profile numbers in a list -- so we can plot these specific profiles 
prof_list = prof_list.tolist()
prof_list_ints = []
for j in range(0,len(prof_list)):
    b = int(prof_list[j])
    prof_list_ints.append(b)
#--------------------------------------------------------------------
# do these profiles span a year's time? -- we need annual seasonal cycle of profiles
# convert epoch times to dateobjects to datestrings
datestrs=[]
for i in range(0,len(date[0][:])):
    a = datetime.fromordinal(int(date[0][i])) # fromordinal takes the 6-digit float and converts from int to
    # date after epoch in a datetime object
    b = a.strftime('%m/%d/%Y') # convert datetime object to string
    datestrs = np.append(datestrs,b)
    
#--------------------------------------------------------------------
# print corresponding profiles in region with their dates to see what kind of mixed layer we should see 
for i in prof_list_ints:
    print('profile #:', i, 'date', datestrs[i])


ax.set_extent([-60,-35,45,65], crs=ccrs.PlateCarree())
# Out:
# profile #: 19 date 09/19/2012
# profile #: 21 date 10/10/2012
# profile #: 23 date 10/30/2012
# profile #: 25 date 11/19/2012
# profile #: 26 date 11/30/2012
# profile #: 27 date 12/10/2012
# profile #: 28 date 12/20/2012
# profile #: 29 date 12/30/2012
# profile #: 30 date 01/09/2013
# profile #: 109 date 03/23/2015
# profile #: 134 date 12/03/2015
# profile #: 135 date 12/13/2015
# profile #: 136 date 12/23/2015
# profile #: 137 date 01/02/2016
# profile #: 138 date 01/12/2016
# profile #: 139 date 01/22/2016
# profile #: 140 date 02/02/2016
# profile #: 141 date 02/12/2016
# profile #: 142 date 02/22/2016
# profile #: 143 date 03/03/2016
# profile #: 144 date 03/13/2016
# profile #: 145 date 03/23/2016
# profile #: 218 date 04/05/2018
# profile #: 220 date 04/25/2018
# profile #: 221 date 05/05/2018
# profile #: 232 date 08/25/2018
# profile #: 233 date 09/04/2018
# profile #: 234 date 09/14/2018

# %%
np.shape(datestrs)
# Out:
# (316,)

# %%
depth = gsw.z_from_p(pres,lat)

depth = -1*depth
depth1 = gsw.z_from_p(pres,lat)
depth1 = -1*depth1

# %%
prof_cool = [25,26,27,28,29,109,134,135,136,137,218,220,221]
prof_warm = [232,233,234]

# %%
# plotting temperature profiles of profs in close proximity region
fig = plt.figure(figsize=(10,10))
ax = plt.axes()

plt.xlabel('Temperature ($^\circ$C)')
plt.ylabel('Depth (m)')
plt.grid(alpha=0.5)
plt.title('Temperature vs Pressure for single Argo Profiles')
# for i in prof_list_ints:
#     plt.plot(temp[i][:],depth[0][:])
for q in prof_cool:
    plt.plot(temp[q],depth[0][:],c='blue')
    
for w in prof_warm:
    plt.plot(temp[w],depth[0][:],c='red')
    
# plt.ylim([0, 1000])
plt.gca().invert_yaxis()

# %%
profs_cool
# Out:
# range(25, 29)

# %%
print(lat[109],long[109])
print(lat[29]),long[29]
print(lat[19],long[19])
print(lat[223],long[223])
print(lat[234],long[234])
#long limits: 109 - 19, -52.654 to -48.405
#lat limits: 223 - 29, 54.457 to 56.194

# %% [markdown]
# # 2.   Calculate the integrated heat content (Q, in Joules/m2) of your profiles from the surface to a fixed depth. This depth should be equal to or greater than the maximum mixed layer depth estimated during your data-period.

# %%
# Formula p*cp*T (int over depths)

# get average density over all data
# get rid of NaNs
rho_simp = rho[~np.isnan(rho)]
# average density
rho_avg = np.sum(rho_simp)/len(rho_simp)
print('Our average density is:', rho_avg, 'kg/m^3')

# %%
np.shape(depth)
# Out:
# (316, 400)

# %%
np.shape(temp)
# Out:
# (316, 400)

# %%
len(temp[0][:])
# Out:
# 400

# %%
clean_t = temp[~np.isnan(temp)]
clean_dep = depth[~np.isnan(depth)]

# %%
counter = 0
for i in range(0,len(temp[:])): # 202 is where before 1000m
    for j in range(0,202):
        #calculate depth between two data points
        dep_diff = np.absolute(depth[i][j] - depth[i][j])
        xxx = temp[i][j] * dep_diff
        counter = counter + xxx

# %%
# find where 1000m depth is located, its at the 202 index of the each profile's depth data
for i in range(0,len(depth[:])):
    a = depth[i][202]
    if a <= 1000:
        print(i,'no depth over 1000')
# Out:
# 0 no depth over 1000
# 1 no depth over 1000
# 2 no depth over 1000
# 3 no depth over 1000
# 4 no depth over 1000
# 5 no depth over 1000
# 6 no depth over 1000
# 7 no depth over 1000
# 8 no depth over 1000
# 9 no depth over 1000
# 10 no depth over 1000
# 11 no depth over 1000
# 12 no depth over 1000
# 13 no depth over 1000
# 14 no depth over 1000
# 15 no depth over 1000
# 16 no depth over 1000
# 17 no depth over 1000
# 18 no depth over 1000
# 19 no depth over 1000
# 20 no depth over 1000
# 21 no depth over 1000
# 22 no depth over 1000
# 23 no depth over 1000
# 24 no depth over 1000
# 25 no depth over 1000
# 26 no depth over 1000
# 27 no depth over 1000
# 28 no depth over 1000
# 29 no depth over 1000
# 30 no depth over 1000
# 31 no depth over 1000
# 32 no depth over 1000
# 33 no depth over 1000
# 34 no depth over 1000
# 35 no depth over 1000
# 36 no depth over 1000
# 37 no depth over 1000
# 38 no depth over 1000
# 39 no depth over 1000
# 40 no depth over 1000
# 41 no depth over 1000
# 42 no depth over 1000
# 43 no depth over 1000
# 44 no depth over 1000
# 45 no depth over 1000
# 46 no depth over 1000
# 47 no depth over 1000
# 48 no depth over 1000
# 49 no depth over 1000
# 50 no depth over 1000
# 51 no depth over 1000
# 52 no depth over 1000
# 53 no depth over 1000
# 54 no depth over 1000
# 55 no depth over 1000
# 56 no depth over 1000
# 57 no depth over 1000
# 58 no depth over 1000
# 59 no depth over 1000
# 60 no depth over 1000
# 61 no depth over 1000
# 62 no depth over 1000
# 63 no depth over 1000
# 64 no depth over 1000
# 65 no depth over 1000
# 66 no depth over 1000
# 67 no depth over 1000
# 68 no depth over 1000
# 69 no depth over 1000
# 70 no depth over 1000
# 71 no depth over 1000
# 72 no depth over 1000
# 73 no depth over 1000
# 74 no depth over 1000
# 75 no depth over 1000
# 76 no depth over 1000
# 77 no depth over 1000
# 78 no depth over 1000
# 79 no depth over 1000
# 80 no depth over 1000
# 81 no depth over 1000
# 82 no depth over 1000
# 83 no depth over 1000
# 84 no depth over 1000
# 85 no depth over 1000
# 86 no depth over 1000
# 87 no depth over 1000
# 88 no depth over 1000
# 89 no depth over 1000
# 90 no depth over 1000
# 91 no depth over 1000
# 92 no depth over 1000
# 93 no depth over 1000
# 94 no depth over 1000
# 95 no depth over 1000
# 96 no depth over 1000
# 97 no depth over 1000
# 98 no depth over 1000
# 99 no depth over 1000
# 100 no depth over 1000
# 101 no depth over 1000
# 102 no depth over 1000
# 103 no depth over 1000
# 104 no depth over 1000
# 105 no depth over 1000
# 106 no depth over 1000
# 107 no depth over 1000
# 108 no depth over 1000
# 109 no depth over 1000
# 110 no depth over 1000
# 111 no depth over 1000
# 112 no depth over 1000
# 113 no depth over 1000
# 114 no depth over 1000
# 115 no depth over 1000
# 116 no depth over 1000
# 117 no depth over 1000
# 118 no depth over 1000
# 119 no depth over 1000
# 120 no depth over 1000
# 121 no depth over 1000
# 122 no depth over 1000
# 123 no depth over 1000
# 124 no depth over 1000
# 125 no depth over 1000
# 126 no depth over 1000
# 127 no depth over 1000
# 128 no depth over 1000
# 129 no depth over 1000
# 130 no depth over 1000
# 131 no depth over 1000
# 132 no depth over 1000
# 133 no depth over 1000
# 134 no depth over 1000
# 135 no depth over 1000
# 136 no depth over 1000
# 137 no depth over 1000
# 138 no depth over 1000
# 139 no depth over 1000
# 140 no depth over 1000
# 141 no depth over 1000
# 142 no depth over 1000
# 143 no depth over 1000
# 144 no depth over 1000
# 145 no depth over 1000
# 146 no depth over 1000
# 147 no depth over 1000
# 148 no depth over 1000
# 149 no depth over 1000
# 150 no depth over 1000
# 151 no depth over 1000
# 152 no depth over 1000
# 153 no depth over 1000
# 154 no depth over 1000
# 155 no depth over 1000
# 156 no depth over 1000
# 157 no depth over 1000
# 158 no depth over 1000
# 159 no depth over 1000
# 160 no depth over 1000
# 161 no depth over 1000
# 162 no depth over 1000
# 163 no depth over 1000
# 164 no depth over 1000
# 165 no depth over 1000
# 166 no depth over 1000
# 167 no depth over 1000
# 168 no depth over 1000
# 169 no depth over 1000
# 170 no depth over 1000
# 171 no depth over 1000
# 172 no depth over 1000
# 173 no depth over 1000
# 174 no depth over 1000
# 175 no depth over 1000
# 176 no depth over 1000
# 177 no depth over 1000
# 178 no depth over 1000
# 179 no depth over 1000
# 180 no depth over 1000
# 181 no depth over 1000
# 182 no depth over 1000
# 183 no depth over 1000
# 184 no depth over 1000
# 185 no depth over 1000
# 186 no depth over 1000
# 187 no depth over 1000
# 188 no depth over 1000
# 189 no depth over 1000
# 190 no depth over 1000
# 191 no depth over 1000
# 192 no depth over 1000
# 193 no depth over 1000
# 194 no depth over 1000
# 195 no depth over 1000
# 196 no depth over 1000
# 197 no depth over 1000
# 198 no depth over 1000
# 199 no depth over 1000
# 200 no depth over 1000
# 201 no depth over 1000
# 202 no depth over 1000
# 203 no depth over 1000
# 204 no depth over 1000
# 205 no depth over 1000
# 206 no depth over 1000
# 207 no depth over 1000
# 208 no depth over 1000
# 209 no depth over 1000
# 210 no depth over 1000
# 211 no depth over 1000
# 212 no depth over 1000
# 213 no depth over 1000
# 214 no depth over 1000
# 215 no depth over 1000
# 216 no depth over 1000
# 217 no depth over 1000
# 218 no depth over 1000
# 219 no depth over 1000
# 220 no depth over 1000
# 221 no depth over 1000
# 222 no depth over 1000
# 223 no depth over 1000
# 224 no depth over 1000
# 225 no depth over 1000
# 226 no depth over 1000
# 227 no depth over 1000
# 228 no depth over 1000
# 229 no depth over 1000
# 230 no depth over 1000
# 231 no depth over 1000
# 232 no depth over 1000
# 233 no depth over 1000
# 234 no depth over 1000
# 235 no depth over 1000
# 236 no depth over 1000
# 237 no depth over 1000
# 238 no depth over 1000
# 239 no depth over 1000
# 240 no depth over 1000
# 241 no depth over 1000
# 242 no depth over 1000
# 243 no depth over 1000
# 244 no depth over 1000
# 245 no depth over 1000
# 246 no depth over 1000
# 247 no depth over 1000
# 248 no depth over 1000
# 249 no depth over 1000
# 250 no depth over 1000
# 251 no depth over 1000
# 252 no depth over 1000
# 253 no depth over 1000
# 254 no depth over 1000
# 255 no depth over 1000
# 256 no depth over 1000
# 257 no depth over 1000
# 258 no depth over 1000
# 259 no depth over 1000
# 260 no depth over 1000
# 261 no depth over 1000
# 262 no depth over 1000
# 263 no depth over 1000
# 264 no depth over 1000
# 265 no depth over 1000
# 266 no depth over 1000
# 267 no depth over 1000
# 268 no depth over 1000
# 269 no depth over 1000
# 270 no depth over 1000
# 271 no depth over 1000
# 272 no depth over 1000
# 273 no depth over 1000
# 274 no depth over 1000
# 275 no depth over 1000
# 276 no depth over 1000
# 277 no depth over 1000
# 278 no depth over 1000
# 279 no depth over 1000
# 280 no depth over 1000
# 281 no depth over 1000
# 282 no depth over 1000
# 283 no depth over 1000
# 284 no depth over 1000
# 285 no depth over 1000
# 286 no depth over 1000
# 287 no depth over 1000
# 288 no depth over 1000
# 289 no depth over 1000
# 290 no depth over 1000
# 291 no depth over 1000
# 292 no depth over 1000
# 293 no depth over 1000
# 294 no depth over 1000
# 295 no depth over 1000
# 296 no depth over 1000
# 297 no depth over 1000
# 298 no depth over 1000
# 299 no depth over 1000
# 300 no depth over 1000
# 301 no depth over 1000
# 302 no depth over 1000
# 303 no depth over 1000
# 304 no depth over 1000
# 305 no depth over 1000
# 306 no depth over 1000
# 307 no depth over 1000
# 308 no depth over 1000
# 309 no depth over 1000
# 310 no depth over 1000
# 311 no depth over 1000
# 312 no depth over 1000
# 313 no depth over 1000
# 314 no depth over 1000
# 315 no depth over 1000

# %%
np.shape(clean_dep)
# Out:
# (126400,)

# %%
np.shape(clean_t)
# Out:
# (119955,)

# %%
np.isnan(CT)
# Out:
# array([[ True, False, False, ...,  True,  True,  True],
#        [ True, False, False, ..., False, False, False],
#        [ True,  True, False, ..., False, False, False],
#        ...,
#        [ True,  True, False, ...,  True,  True,  True],
#        [ True,  True, False, ...,  True,  True,  True],
#        [ True, False, False, ...,  True,  True,  True]])

# %%
clean_t
# Out:
# array([5.3397837, 5.3347692, 5.3446593, ..., 3.4570038, 3.454104 ,
#        3.4512038], dtype=float32)

# %%
# temperature has NaNs and is the limitng factor, omit depth data 
for i in range(0,len(temp[:])):
    for j in range(0,len(temp[0][:])):
        if temp[i][j] == np.float32('nan'):
            print('this value is nan')
            depth1[i][j] = np.NaN

# %%
temp[0][0] == wnp.float32('nan')
# Out:
# False

# %%
type(temp[0][0])
# Out:
# numpy.float32

# %%
depth1[0][0]
# Out:
# 0.9911534165223485

# %%
type(np.NaN)
# Out:
# float

# %%
depth1
# Out:
# array([[9.91153417e-01, 5.94684830e+00, 1.09024229e+01, ...,
#         1.95913375e+03, 1.96404311e+03, 1.96895236e+03],
#        [9.91104757e-01, 5.94655635e+00, 1.09018876e+01, ...,
#         1.95903759e+03, 1.96394671e+03, 1.96885572e+03],
#        [9.91066996e-01, 5.94632978e+00, 1.09014723e+01, ...,
#         1.95896297e+03, 1.96387190e+03, 1.96878072e+03],
#        ...,
#        [9.90804865e-01, 5.94475702e+00, 1.08985889e+01, ...,
#         1.95844495e+03, 1.96335258e+03, 1.96826011e+03],
#        [9.90781220e-01, 5.94461515e+00, 1.08983288e+01, ...,
#         1.95839822e+03, 1.96330574e+03, 1.96821315e+03],
#        [9.90744308e-01, 5.94439368e+00, 1.08979228e+01, ...,
#         1.95832528e+03, 1.96323261e+03, 1.96813983e+03]])

# %%
clean_dept = depth1[~np.isnan(depth1)]

# %%
len(clean_dept)
# Out:
# 0

# %%
np.float
# Out:
# array([], dtype=float64)

# %%
clean_t
# Out:
# array([5.3397837, 5.3347692, 5.3446593, ..., 3.4570038, 3.454104 ,
#        3.4512038], dtype=float32)

# %%
np.NaN
# Out:
# nan

# %%
type(temp[0][0])
# Out:
# numpy.float32

# %%
type(np.NaN,type=32)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-163-d266b747a9fb> in <module>
# ----> 1 type(np.NaN,type=32)
#
# TypeError: type() takes 1 or 3 arguments
